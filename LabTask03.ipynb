# %% [markdown]
# <a href="https://colab.research.google.com/github/T-biohazard/CSE366_AI_LABs/blob/main/LabTask03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ![x6.png](data:image/png;base64,...)

# %% [markdown]
# Consider a household trading agent that monitors the price of some commodity, such as toilet paper, by checking for deals online, as well as how much the household has in stock. It must decide whether to order more and how much to order. Assume the percepts are the price and the amount in stock. The command is the number of units the agent decides to order (which is zero if the agent does not order any). A percept trace specifies for each time point (e.g., each day) the price at that time and the amount in stock at that time.

# %% [markdown]
# Utilities

# %%
def argmaxall(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxall returns a list of all of the elements with maximal value.
    """
    maxv = -math.inf       # negative infinity
    maxvals = []      # list of maximal elements
    for (e,v) in gen:
        if v>maxv:
            maxvals,maxv = [e], v
        elif v==maxv:
            maxvals.append(e)
    return maxvals

# %%
def argmaxe(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxe returns an element with maximal value.
    If there are multiple elements with the max value, one is returned at random.
    """
    return random.choice(argmaxall(gen))

# %%
def argmax(lst):
    """returns maximum index in a list"""
    return argmaxe(enumerate(lst))

# %%
def argmaxd(dct):
   """returns the arg max of a dictionary dct"""
   return argmaxe(dct.items())

# %%
def flip(prob):
    """return true with probability prob"""
    return random.random() < prob

# %%
def select_from_dist(item_prob_dist):
  #{6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2}
    """ returns a value from a distribution.
    item_prob_dist is an item:probability dictionary, where the
        probabilities sum to 1.
    returns an item chosen in proportion to its probability
    """
    ranreal = random.random()
    for (it,prob) in item_prob_dist.items():
        if ranreal < prob:
            return it
        else:
            ranreal -= prob
    raise RuntimeError(f"{item_prob_dist} is not a probability distribution")

# %% [markdown]
# Display Class

# %%
class Displayable(object):
    """Class that uses 'display'.
    The amount of detail is controlled by max_display_level
    """
    max_display_level = 1   # can be overridden in subclasses or instances

    def display(self,level,*args,**nargs):
        """print the arguments if level is less than or equal to the
        current max_display_level.
        level is an integer.
        the other arguments are whatever arguments print can take.
        """

        if level <= self.max_display_level:
            print(*args, **nargs)  ##if error you are using Python2 not Python3

# %%
class Plot_history(object):
    """Set up the plot for history of price and number in stock"""
    def __init__(self, ag, env):
        self.ag = ag
        self.env = env
        plt.ion()
        plt.xlabel("Time")
        plt.ylabel("Value")


    def plot_env_hist(self):
        """plot history of price and instock"""
        num = len(env.stock_history)
        plt.plot(range(num),env.price_history,label="Price")
        plt.plot(range(num),env.stock_history,label="In stock")
        plt.legend()
        #plt.draw()

    def plot_agent_hist(self):
        """plot history of buying"""
        num = len(ag.buy_history)
        plt.bar(range(1,num+1), ag.buy_history, label="Bought")
        plt.legend()
        #plt.draw()

# %% [markdown]
# Agent Conntroller

# %%
#from display import Displayable

class Agent(Displayable):

    def initial_action(self, percept):
        """return the initial action."""
        return self.select_action(percept)   # same as select_action

    def select_action(self, percept):
        """return the next action (and update internal state) given percept
        percept is variable:value dictionary
        """
        raise NotImplementedError("go")   # abstract method

# %% [markdown]
# Environment

# %%
class Environment(Displayable):
    def initial_percept(self):
        """returns the initial percept for the agent"""
        raise NotImplementedError("initial_percept")   # abstract method

    def do(self, action):
        """does the action in the environment
        returns the next percept """
        raise NotImplementedError("Environment.do")   # abstract method

# %% [markdown]
# Simulate

# %%
class Simulate(Displayable):
    """simulate the interaction between the agent and the environment
    for n time steps.
    Returns a pair of the agent state and the environment state.
    """
    def __init__(self,agent, environment):
        self.agent = agent
        self.env = environment
        self.percept = self.env.initial_percept()
        self.percept_history = [self.percept]
        self.action_history = []

    def go(self, n):
        for i in range(n):
            action = self.agent.select_action(self.percept)
            print(f"i={i} action={action}")

            self.percept = self.env.do(action,i)
            print(f"      percept={self.percept}")

# %% [markdown]
# TP Env

# %%
class TP_env(Environment):
    price_delta = [0, 0, 0, 21, 0, 20, 0, -64, 0, 0, 23, 0, 0, 0, -35,
        0, 76, 0, -41, 0, 0, 0, 21, 0, 5, 0, 5, 0, 0, 0, 5, 0, -15, 0, 5,
       0, 5, 0, -115, 0, 115, 0, 5, 0, -15, 0, 5, 0, 5, 0, 0, 0, 5, 0,
       -59, 0, 44, 0, 5, 0, 5, 0, 0, 0, 5, 0, -65, 50, 0, 5, 0, 5, 0, 0,
       0, 5, 0]
    sd = 5  # noise standard deviation

    def __init__(self):
        """paper buying agent"""
        self.time=0
        self.stock=20
        self.stock_history = []  # memory of the stock history
        self.price_history = []  # memory of the price history

    def initial_percept(self):
        """return initial percept"""
        self.stock_history.append(self.stock)
        self.price = round(234+self.sd*random.gauss(0,1))
        self.price_history.append(self.price)
        #print(f"Initial price: {self.price} ,instock: {self.stock}")
        return {'price': self.price,
                'instock': self.stock}

    def do(self, action, time_unit):
        """does action (buy) and returns percept consisting of price and instock"""
        used = select_from_dist({6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2})
        print(f"i={time_unit} used={used}")
        # used = select_from_dist({7:0.1, 6:0.2, 5:0.2, 4:0.3, 3:0.1, 2:0.1}) # uses more paper
        bought = action['buy']
        self.stock = self.stock+bought-used
        self.stock_history.append(self.stock)
        self.time += 1
        self.price =  round(self.price
                        + self.price_delta[self.time%len(self.price_delta)] # repeating pattern
                        + self.sd*random.gauss(0,1)) # plus randomness
        self.price_history.append(self.price)
        return {'price': self.price,
                'instock': self.stock}

# %%
class TP_agent(Agent):
    def __init__(self):
        self.spent = 0
        percept = env.initial_percept()
        self.ave = self.last_price = percept['price']
        self.instock = percept['instock']
        self.buy_history = []

    def select_action(self, percept):
        """return next action to carry out
        """
        self.last_price = percept['price']
        self.ave = self.ave+(self.last_price-self.ave)*0.05
        self.instock = percept['instock']
        if self.last_price < 0.9*self.ave and self.instock < 60:
            tobuy = 48
        elif self.instock < 12:
            tobuy = 12
        else:
            tobuy = 0
        self.spent += tobuy*self.last_price
        self.buy_history.append(tobuy)
        #print(f"agent buy:{tobuy}")
        return {'buy': tobuy}

# %%
env = TP_env()
ag = TP_agent()
sim = Simulate(ag,env)
sim.go(10)
ag.spent/env.time
# Out:
# i=0 action={'buy': 0}
# i=0 used=3
#       percept={'price': 234, 'instock': 17}
# i=1 action={'buy': 0}
# i=1 used=2
#       percept={'price': 231, 'instock': 15}
# i=2 action={'buy': 0}
# i=2 used=1
#       percept={'price': 253, 'instock': 14}
# i=3 action={'buy': 0}
# i=3 used=6
#       percept={'price': 257, 'instock': 8}
# i=4 action={'buy': 12}
# i=4 used=3
#       percept={'price': 277, 'instock': 17}
# i=5 action={'buy': 0}
# i=5 used=5
#       percept={'price': 278, 'instock': 12}
# i=6 action={'buy': 0}
# i=6 used=3
#       percept={'price': 208, 'instock': 9}
# i=7 action={'buy': 48}
# i=7 used=1
#       percept={'price': 206, 'instock': 56}
# i=8 action={'buy': 48}
# i=8 used=5
#       percept={'price': 209, 'instock': 99}
# i=9 action={'buy': 0}
# i=9 used=4
#       percept={'price': 234, 'instock': 95}
# 2295.6

# %%
sim.go(100);
# Out:
# i=0 action={'buy': 0}
# i=0 used=2
#       percept={'price': 229, 'instock': 93}
# i=1 action={'buy': 0}
# i=1 used=2
#       percept={'price': 228, 'instock': 91}
# i=2 action={'buy': 0}
# i=2 used=3
#       percept={'price': 220, 'instock': 88}
# i=3 action={'buy': 0}
# i=3 used=3
#       percept={'price': 176, 'instock': 85}
# i=4 action={'buy': 0}
# i=4 used=2
#       percept={'price': 177, 'instock': 83}
# i=5 action={'buy': 0}
# i=5 used=1
#       percept={'price': 249, 'instock': 82}
# i=6 action={'buy': 0}
# i=6 used=2
#       percept={'price': 251, 'instock': 80}
# i=7 action={'buy': 0}
# i=7 used=3
#       percept={'price': 214, 'instock': 77}
# i=8 action={'buy': 0}
# i=8 used=6
#       percept={'price': 214, 'instock': 71}
# i=9 action={'buy': 0}
# i=9 used=3
#       percept={'price': 209, 'instock': 68}
# i=10 action={'buy': 0}
# i=10 used=1
#       percept={'price': 209, 'instock': 67}
# i=11 action={'buy': 0}
# i=11 used=6
#       percept={'price': 228, 'instock': 61}
# i=12 action={'buy': 0}
# i=12 used=6
#       percept={'price': 238, 'instock': 55}
# i=13 action={'buy': 0}
# i=13 used=3
#       percept={'price': 249, 'instock': 52}
# i=14 action={'buy': 0}
# i=14 used=4
#       percept={'price': 244, 'instock': 48}
# i=15 action={'buy': 0}
# i=15 used=2
#       percept={'price': 246, 'instock': 46}
# i=16 action={'buy': 0}
# i=16 used=3
#       percept={'price': 240, 'instock': 43}
# i=17 action={'buy': 0}
# i=17 used=3
#       percept={'price': 242, 'instock': 40}
# i=18 action={'buy': 0}
# i=18 used=1
#       percept={'price': 235, 'instock': 39}
# i=19 action={'buy': 0}
# i=19 used=4
#       percept={'price': 244, 'instock': 35}
# i=20 action={'buy': 0}
# i=20 used=3
#       percept={'price': 242, 'instock': 32}
# i=21 action={'buy': 0}
# i=21 used=3
#       percept={'price': 226, 'instock': 29}
# i=22 action={'buy': 0}
# i=22 used=2
#       percept={'price': 219, 'instock': 27}
# i=23 action={'buy': 0}
# i=23 used=4
#       percept={'price': 223, 'instock': 23}
# i=24 action={'buy': 0}
# i=24 used=3
#       percept={'price': 225, 'instock': 20}
# i=25 action={'buy': 0}
# i=25 used=2
#       percept={'price': 225, 'instock': 18}
# i=26 action={'buy': 0}
# i=26 used=2
#       percept={'price': 222, 'instock': 16}
# i=27 action={'buy': 0}
# i=27 used=1
#       percept={'price': 99, 'instock': 15}
# i=28 action={'buy': 48}
# i=28 used=3
#       percept={'price': 100, 'instock': 60}
# i=29 action={'buy': 0}
# i=29 used=2
#       percept={'price': 210, 'instock': 58}
# i=30 action={'buy': 0}
# i=30 used=5
#       percept={'price': 206, 'instock': 53}
# i=31 action={'buy': 0}
# i=31 used=2
#       percept={'price': 208, 'instock': 51}
# i=32 action={'buy': 0}
# i=32 used=5
#       percept={'price': 200, 'instock': 46}
# i=33 action={'buy': 0}
# i=33 used=3
#       percept={'price': 180, 'instock': 43}
# i=34 action={'buy': 48}
# i=34 used=4
#       percept={'price': 177, 'instock': 87}
# i=35 action={'buy': 0}
# i=35 used=3
#       percept={'price': 184, 'instock': 84}
# i=36 action={'buy': 0}
# i=36 used=1
#       percept={'price': 184, 'instock': 83}
# i=37 action={'buy': 0}
# i=37 used=2
#       percept={'price': 184, 'instock': 81}
# i=38 action={'buy': 0}
# i=38 used=3
#       percept={'price': 179, 'instock': 78}
# i=39 action={'buy': 0}
# i=39 used=5
#       percept={'price': 186, 'instock': 73}
# i=40 action={'buy': 0}
# i=40 used=5
#       percept={'price': 179, 'instock': 68}
# i=41 action={'buy': 0}
# i=41 used=2
#       percept={'price': 191, 'instock': 66}
# i=42 action={'buy': 0}
# i=42 used=3
#       percept={'price': 184, 'instock': 63}
# i=43 action={'buy': 0}
# i=43 used=3
#       percept={'price': 126, 'instock': 60}
# i=44 action={'buy': 0}
# i=44 used=1
#       percept={'price': 114, 'instock': 59}
# i=45 action={'buy': 48}
# i=45 used=3
#       percept={'price': 160, 'instock': 104}
# i=46 action={'buy': 0}
# i=46 used=1
#       percept={'price': 164, 'instock': 103}
# i=47 action={'buy': 0}
# i=47 used=1
#       percept={'price': 164, 'instock': 102}
# i=48 action={'buy': 0}
# i=48 used=5
#       percept={'price': 161, 'instock': 97}
# i=49 action={'buy': 0}
# i=49 used=3
#       percept={'price': 167, 'instock': 94}
# i=50 action={'buy': 0}
# i=50 used=1
#       percept={'price': 170, 'instock': 93}
# i=51 action={'buy': 0}
# i=51 used=1
#       percept={'price': 165, 'instock': 92}
# i=52 action={'buy': 0}
# i=52 used=2
#       percept={'price': 168, 'instock': 90}
# i=53 action={'buy': 0}
# i=53 used=3
#       percept={'price': 177, 'instock': 87}
# i=54 action={'buy': 0}
# i=54 used=4
#       percept={'price': 173, 'instock': 83}
# i=55 action={'buy': 0}
# i=55 used=6
#       percept={'price': 106, 'instock': 77}
# i=56 action={'buy': 0}
# i=56 used=4
#       percept={'price': 152, 'instock': 73}
# i=57 action={'buy': 0}
# i=57 used=3
#       percept={'price': 158, 'instock': 70}
# i=58 action={'buy': 0}
# i=58 used=3
#       percept={'price': 168, 'instock': 67}
# i=59 action={'buy': 0}
# i=59 used=5
#       percept={'price': 165, 'instock': 62}
# i=60 action={'buy': 0}
# i=60 used=3
#       percept={'price': 180, 'instock': 59}
# i=61 action={'buy': 0}
# i=61 used=2
#       percept={'price': 184, 'instock': 57}
# i=62 action={'buy': 0}
# i=62 used=1
#       percept={'price': 187, 'instock': 56}
# i=63 action={'buy': 0}
# i=63 used=5
#       percept={'price': 181, 'instock': 51}
# i=64 action={'buy': 0}
# i=64 used=4
#       percept={'price': 180, 'instock': 47}
# i=65 action={'buy': 0}
# i=65 used=5
#       percept={'price': 183, 'instock': 42}
# i=66 action={'buy': 0}
# i=66 used=2
#       percept={'price': 179, 'instock': 40}
# i=67 action={'buy': 0}
# i=67 used=4
#       percept={'price': 168, 'instock': 36}
# i=68 action={'buy': 0}
# i=68 used=5
#       percept={'price': 176, 'instock': 31}
# i=69 action={'buy': 0}
# i=69 used=1
#       percept={'price': 186, 'instock': 30}
# i=70 action={'buy': 0}
# i=70 used=6
#       percept={'price': 184, 'instock': 24}
# i=71 action={'buy': 0}
# i=71 used=3
#       percept={'price': 200, 'instock': 21}
# i=72 action={'buy': 0}
# i=72 used=5
#       percept={'price': 198, 'instock': 16}
# i=73 action={'buy': 0}
# i=73 used=3
#       percept={'price': 127, 'instock': 13}
# i=74 action={'buy': 48}
# i=74 used=4
#       percept={'price': 127, 'instock': 57}
# i=75 action={'buy': 48}
# i=75 used=2
#       percept={'price': 132, 'instock': 103}
# i=76 action={'buy': 0}
# i=76 used=2
#       percept={'price': 149, 'instock': 101}
# i=77 action={'buy': 0}
# i=77 used=6
#       percept={'price': 139, 'instock': 95}
# i=78 action={'buy': 0}
# i=78 used=3
#       percept={'price': 140, 'instock': 92}
# i=79 action={'buy': 0}
# i=79 used=5
#       percept={'price': 139, 'instock': 87}
# i=80 action={'buy': 0}
# i=80 used=5
#       percept={'price': 106, 'instock': 82}
# i=81 action={'buy': 0}
# i=81 used=1
#       percept={'price': 108, 'instock': 81}
# i=82 action={'buy': 0}
# i=82 used=2
#       percept={'price': 194, 'instock': 79}
# i=83 action={'buy': 0}
# i=83 used=3
#       percept={'price': 191, 'instock': 76}
# i=84 action={'buy': 0}
# i=84 used=1
#       percept={'price': 149, 'instock': 75}
# i=85 action={'buy': 0}
# i=85 used=3
#       percept={'price': 140, 'instock': 72}
# i=86 action={'buy': 0}
# i=86 used=1
#       percept={'price': 145, 'instock': 71}
# i=87 action={'buy': 0}
# i=87 used=3
#       percept={'price': 142, 'instock': 68}
# i=88 action={'buy': 0}
# i=88 used=3
#       percept={'price': 164, 'instock': 65}
# i=89 action={'buy': 0}
# i=89 used=6
#       percept={'price': 164, 'instock': 59}
# i=90 action={'buy': 0}
# i=90 used=6
#       percept={'price': 172, 'instock': 53}
# i=91 action={'buy': 0}
# i=91 used=6
#       percept={'price': 169, 'instock': 47}
# i=92 action={'buy': 0}
# i=92 used=4
#       percept={'price': 165, 'instock': 43}
# i=93 action={'buy': 0}
# i=93 used=2
#       percept={'price': 170, 'instock': 41}
# i=94 action={'buy': 0}
# i=94 used=3
#       percept={'price': 172, 'instock': 38}
# i=95 action={'buy': 0}
# i=95 used=2
#       percept={'price': 177, 'instock': 36}
# i=96 action={'buy': 0}
# i=96 used=2
#       percept={'price': 180, 'instock': 34}
# i=97 action={'buy': 0}
# i=97 used=2
#       percept={'price': 182, 'instock': 32}
# i=98 action={'buy': 0}
# i=98 used=3
#       percept={'price': 163, 'instock': 29}
# i=99 action={'buy': 0}
# i=99 used=1
#       percept={'price': 166, 'instock': 28}

# %%
sim.go(100);
print(f"agent spent ${ag.spent/100}")
pl = Plot_history(ag,env); pl.plot_env_hist(); pl.plot_agent_hist()
# Out:
# i=0 action={'buy': 0}
# i=0 used=4
#       percept={'price': 173, 'instock': 24}
# i=1 action={'buy': 0}
# i=1 used=1
#       percept={'price': 175, 'instock': 23}
# i=2 action={'buy': 0}
# i=2 used=6
#       percept={'price': 179, 'instock': 17}
# i=3 action={'buy': 0}
# i=3 used=1
#       percept={'price': 185, 'instock': 16}
# i=4 action={'buy': 0}
# i=4 used=1
#       percept={'price': 74, 'instock': 15}
# i=5 action={'buy': 48}
# i=5 used=3
#       percept={'price': 68, 'instock': 60}
# i=6 action={'buy': 0}
# i=6 used=5
#       percept={'price': 186, 'instock': 55}
# i=7 action={'buy': 0}
# i=7 used=1
#       percept={'price': 187, 'instock': 54}
# i=8 action={'buy': 0}
# i=8 used=6
#       percept={'price': 186, 'instock': 48}
# i=9 action={'buy': 0}
# i=9 used=4
#       percept={'price': 189, 'instock': 44}
# i=10 action={'buy': 0}
# i=10 used=3
#       percept={'price': 180, 'instock': 41}
# i=11 action={'buy': 0}
# i=11 used=3
#       percept={'price': 175, 'instock': 38}
# i=12 action={'buy': 0}
# i=12 used=1
#       percept={'price': 172, 'instock': 37}
# i=13 action={'buy': 0}
# i=13 used=2
#       percept={'price': 176, 'instock': 35}
# i=14 action={'buy': 0}
# i=14 used=5
#       percept={'price': 182, 'instock': 30}
# i=15 action={'buy': 0}
# i=15 used=3
#       percept={'price': 180, 'instock': 27}
# i=16 action={'buy': 0}
# i=16 used=1
#       percept={'price': 179, 'instock': 26}
# i=17 action={'buy': 0}
# i=17 used=2
#       percept={'price': 177, 'instock': 24}
# i=18 action={'buy': 0}
# i=18 used=3
#       percept={'price': 176, 'instock': 21}
# i=19 action={'buy': 0}
# i=19 used=6
#       percept={'price': 168, 'instock': 15}
# i=20 action={'buy': 0}
# i=20 used=4
#       percept={'price': 114, 'instock': 11}
# i=21 action={'buy': 48}
# i=21 used=5
#       percept={'price': 115, 'instock': 54}
# i=22 action={'buy': 48}
# i=22 used=3
#       percept={'price': 157, 'instock': 99}
# i=23 action={'buy': 0}
# i=23 used=3
#       percept={'price': 158, 'instock': 96}
# i=24 action={'buy': 0}
# i=24 used=3
#       percept={'price': 162, 'instock': 93}
# i=25 action={'buy': 0}
# i=25 used=2
#       percept={'price': 164, 'instock': 91}
# i=26 action={'buy': 0}
# i=26 used=3
#       percept={'price': 174, 'instock': 88}
# i=27 action={'buy': 0}
# i=27 used=2
#       percept={'price': 171, 'instock': 86}
# i=28 action={'buy': 0}
# i=28 used=3
#       percept={'price': 170, 'instock': 83}
# i=29 action={'buy': 0}
# i=29 used=3
#       percept={'price': 170, 'instock': 80}
# i=30 action={'buy': 0}
# i=30 used=5
#       percept={'price': 176, 'instock': 75}
# i=31 action={'buy': 0}
# i=31 used=4
#       percept={'price': 170, 'instock': 71}
# i=32 action={'buy': 0}
# i=32 used=5
#       percept={'price': 108, 'instock': 66}
# i=33 action={'buy': 0}
# i=33 used=3
#       percept={'price': 160, 'instock': 63}
# i=34 action={'buy': 0}
# i=34 used=3
#       percept={'price': 152, 'instock': 60}
# i=35 action={'buy': 0}
# i=35 used=5
#       percept={'price': 154, 'instock': 55}
# i=36 action={'buy': 0}
# i=36 used=3
#       percept={'price': 153, 'instock': 52}
# i=37 action={'buy': 0}
# i=37 used=5
#       percept={'price': 161, 'instock': 47}
# i=38 action={'buy': 0}
# i=38 used=6
#       percept={'price': 166, 'instock': 41}
# i=39 action={'buy': 0}
# i=39 used=2
#       percept={'price': 164, 'instock': 39}
# i=40 action={'buy': 0}
# i=40 used=4
#       percept={'price': 161, 'instock': 35}
# i=41 action={'buy': 0}
# i=41 used=4
#       percept={'price': 164, 'instock': 31}
# i=42 action={'buy': 0}
# i=42 used=4
#       percept={'price': 167, 'instock': 27}
# i=43 action={'buy': 0}
# i=43 used=3
#       percept={'price': 177, 'instock': 24}
# i=44 action={'buy': 0}
# i=44 used=3
#       percept={'price': 174, 'instock': 21}
# i=45 action={'buy': 0}
# i=45 used=5
#       percept={'price': 172, 'instock': 16}
# i=46 action={'buy': 0}
# i=46 used=6
#       percept={'price': 198, 'instock': 10}
# i=47 action={'buy': 12}
# i=47 used=3
#       percept={'price': 197, 'instock': 19}
# i=48 action={'buy': 0}
# i=48 used=3
#       percept={'price': 210, 'instock': 16}
# i=49 action={'buy': 0}
# i=49 used=1
#       percept={'price': 213, 'instock': 15}
# i=50 action={'buy': 0}
# i=50 used=1
#       percept={'price': 154, 'instock': 14}
# i=51 action={'buy': 0}
# i=51 used=3
#       percept={'price': 156, 'instock': 11}
# i=52 action={'buy': 12}
# i=52 used=4
#       percept={'price': 155, 'instock': 19}
# i=53 action={'buy': 0}
# i=53 used=2
#       percept={'price': 182, 'instock': 17}
# i=54 action={'buy': 0}
# i=54 used=6
#       percept={'price': 185, 'instock': 11}
# i=55 action={'buy': 12}
# i=55 used=6
#       percept={'price': 182, 'instock': 17}
# i=56 action={'buy': 0}
# i=56 used=1
#       percept={'price': 180, 'instock': 16}
# i=57 action={'buy': 0}
# i=57 used=6
#       percept={'price': 144, 'instock': 10}
# i=58 action={'buy': 48}
# i=58 used=2
#       percept={'price': 143, 'instock': 56}
# i=59 action={'buy': 48}
# i=59 used=2
#       percept={'price': 226, 'instock': 102}
# i=60 action={'buy': 0}
# i=60 used=3
#       percept={'price': 222, 'instock': 99}
# i=61 action={'buy': 0}
# i=61 used=1
#       percept={'price': 180, 'instock': 98}
# i=62 action={'buy': 0}
# i=62 used=3
#       percept={'price': 186, 'instock': 95}
# i=63 action={'buy': 0}
# i=63 used=2
#       percept={'price': 183, 'instock': 93}
# i=64 action={'buy': 0}
# i=64 used=1
#       percept={'price': 185, 'instock': 92}
# i=65 action={'buy': 0}
# i=65 used=1
#       percept={'price': 201, 'instock': 91}
# i=66 action={'buy': 0}
# i=66 used=3
#       percept={'price': 205, 'instock': 88}
# i=67 action={'buy': 0}
# i=67 used=2
#       percept={'price': 202, 'instock': 86}
# i=68 action={'buy': 0}
# i=68 used=4
#       percept={'price': 206, 'instock': 82}
# i=69 action={'buy': 0}
# i=69 used=1
#       percept={'price': 218, 'instock': 81}
# i=70 action={'buy': 0}
# i=70 used=3
#       percept={'price': 215, 'instock': 78}
# i=71 action={'buy': 0}
# i=71 used=3
#       percept={'price': 216, 'instock': 75}
# i=72 action={'buy': 0}
# i=72 used=3
#       percept={'price': 222, 'instock': 72}
# i=73 action={'buy': 0}
# i=73 used=3
#       percept={'price': 222, 'instock': 69}
# i=74 action={'buy': 0}
# i=74 used=1
#       percept={'price': 224, 'instock': 68}
# i=75 action={'buy': 0}
# i=75 used=3
#       percept={'price': 205, 'instock': 65}
# i=76 action={'buy': 0}
# i=76 used=4
#       percept={'price': 205, 'instock': 61}
# i=77 action={'buy': 0}
# i=77 used=2
#       percept={'price': 203, 'instock': 59}
# i=78 action={'buy': 0}
# i=78 used=1
#       percept={'price': 197, 'instock': 58}
# i=79 action={'buy': 0}
# i=79 used=6
#       percept={'price': 204, 'instock': 52}
# i=80 action={'buy': 0}
# i=80 used=4
#       percept={'price': 204, 'instock': 48}
# i=81 action={'buy': 0}
# i=81 used=1
#       percept={'price': 92, 'instock': 47}
# i=82 action={'buy': 48}
# i=82 used=2
#       percept={'price': 94, 'instock': 93}
# i=83 action={'buy': 0}
# i=83 used=3
#       percept={'price': 202, 'instock': 90}
# i=84 action={'buy': 0}
# i=84 used=3
#       percept={'price': 201, 'instock': 87}
# i=85 action={'buy': 0}
# i=85 used=5
#       percept={'price': 208, 'instock': 82}
# i=86 action={'buy': 0}
# i=86 used=1
#       percept={'price': 204, 'instock': 81}
# i=87 action={'buy': 0}
# i=87 used=3
#       percept={'price': 193, 'instock': 78}
# i=88 action={'buy': 0}
# i=88 used=3
#       percept={'price': 191, 'instock': 75}
# i=89 action={'buy': 0}
# i=89 used=1
#       percept={'price': 201, 'instock': 74}
# i=90 action={'buy': 0}
# i=90 used=6
#       percept={'price': 198, 'instock': 68}
# i=91 action={'buy': 0}
# i=91 used=2
#       percept={'price': 197, 'instock': 66}
# i=92 action={'buy': 0}
# i=92 used=2
#       percept={'price': 192, 'instock': 64}
# i=93 action={'buy': 0}
# i=93 used=3
#       percept={'price': 194, 'instock': 61}
# i=94 action={'buy': 0}
# i=94 used=1
#       percept={'price': 190, 'instock': 60}
# i=95 action={'buy': 0}
# i=95 used=3
#       percept={'price': 196, 'instock': 57}
# i=96 action={'buy': 0}
# i=96 used=1
#       percept={'price': 206, 'instock': 56}
# i=97 action={'buy': 0}
# i=97 used=2
#       percept={'price': 143, 'instock': 54}
# i=98 action={'buy': 48}
# i=98 used=1
#       percept={'price': 143, 'instock': 101}
# i=99 action={'buy': 0}
# i=99 used=1
#       percept={'price': 188, 'instock': 100}
# agent spent $1000.8

# %% [markdown]
# # **Task 1**
# Modify the existing code to fullfill following condtions
#
# 1.   If the last_price is less than 70% of the average (ave) and the instock quantity is less than 30, then set tobuy to 15.
# 2.   Otherwise, if the instock quantity is less than 10, set tobuy to 5.
# If none of the above conditions apply, set tobuy to 0.

# %%
class TP_agent(Agent):
    def __init__(self):
        self.spent = 0
        percept = env.initial_percept()
        self.ave = self.last_price = percept['price']
        self.instock = percept['instock']
        self.buy_history = []

    def select_action(self, percept):
        """return next action to carry out
        """
        self.last_price = percept['price']
        self.ave = self.ave+(self.last_price-self.ave)*0.05
        self.instock = percept['instock']
        if self.last_price < 0.7*self.ave and self.instock < 30:
            tobuy = 15
        elif self.instock < 10:
            tobuy = 5
        else:
            tobuy = 0
        self.spent += tobuy*self.last_price
        self.buy_history.append(tobuy)
        #print(f"agent buy:{tobuy}")
        return {'buy': tobuy}

# %%
env = TP_env()
ag = TP_agent()
sim = Simulate(ag,env)
sim.go(10)
ag.spent/env.time
# Out:
# i=0 action={'buy': 0}
# i=0 used=3
#       percept={'price': 227, 'instock': 17}
# i=1 action={'buy': 0}
# i=1 used=1
#       percept={'price': 229, 'instock': 16}
# i=2 action={'buy': 0}
# i=2 used=3
#       percept={'price': 243, 'instock': 13}
# i=3 action={'buy': 0}
# i=3 used=2
#       percept={'price': 241, 'instock': 11}
# i=4 action={'buy': 0}
# i=4 used=5
#       percept={'price': 258, 'instock': 6}
# i=5 action={'buy': 5}
# i=5 used=1
#       percept={'price': 261, 'instock': 10}
# i=6 action={'buy': 0}
# i=6 used=3
#       percept={'price': 190, 'instock': 7}
# i=7 action={'buy': 5}
# i=7 used=2
#       percept={'price': 186, 'instock': 10}
# i=8 action={'buy': 0}
# i=8 used=4
#       percept={'price': 186, 'instock': 6}
# i=9 action={'buy': 5}
# i=9 used=4
#       percept={'price': 212, 'instock': 7}
# 317.0

# %%
sim.go(100);
# Out:
# i=0 action={'buy': 5}
# i=0 used=3
#       percept={'price': 213, 'instock': 9}
# i=1 action={'buy': 5}
# i=1 used=2
#       percept={'price': 214, 'instock': 12}
# i=2 action={'buy': 0}
# i=2 used=3
#       percept={'price': 207, 'instock': 9}
# i=3 action={'buy': 5}
# i=3 used=3
#       percept={'price': 172, 'instock': 11}
# i=4 action={'buy': 0}
# i=4 used=2
#       percept={'price': 172, 'instock': 9}
# i=5 action={'buy': 5}
# i=5 used=3
#       percept={'price': 243, 'instock': 11}
# i=6 action={'buy': 0}
# i=6 used=4
#       percept={'price': 246, 'instock': 7}
# i=7 action={'buy': 5}
# i=7 used=1
#       percept={'price': 213, 'instock': 11}
# i=8 action={'buy': 0}
# i=8 used=6
#       percept={'price': 201, 'instock': 5}
# i=9 action={'buy': 5}
# i=9 used=3
#       percept={'price': 203, 'instock': 7}
# i=10 action={'buy': 5}
# i=10 used=2
#       percept={'price': 203, 'instock': 10}
# i=11 action={'buy': 0}
# i=11 used=1
#       percept={'price': 225, 'instock': 9}
# i=12 action={'buy': 5}
# i=12 used=2
#       percept={'price': 231, 'instock': 12}
# i=13 action={'buy': 0}
# i=13 used=2
#       percept={'price': 235, 'instock': 10}
# i=14 action={'buy': 0}
# i=14 used=6
#       percept={'price': 237, 'instock': 4}
# i=15 action={'buy': 5}
# i=15 used=3
#       percept={'price': 240, 'instock': 6}
# i=16 action={'buy': 5}
# i=16 used=3
#       percept={'price': 248, 'instock': 8}
# i=17 action={'buy': 5}
# i=17 used=6
#       percept={'price': 247, 'instock': 7}
# i=18 action={'buy': 5}
# i=18 used=3
#       percept={'price': 256, 'instock': 9}
# i=19 action={'buy': 5}
# i=19 used=2
#       percept={'price': 261, 'instock': 12}
# i=20 action={'buy': 0}
# i=20 used=3
#       percept={'price': 252, 'instock': 9}
# i=21 action={'buy': 5}
# i=21 used=3
#       percept={'price': 238, 'instock': 11}
# i=22 action={'buy': 0}
# i=22 used=2
#       percept={'price': 239, 'instock': 9}
# i=23 action={'buy': 5}
# i=23 used=1
#       percept={'price': 252, 'instock': 13}
# i=24 action={'buy': 0}
# i=24 used=5
#       percept={'price': 254, 'instock': 8}
# i=25 action={'buy': 5}
# i=25 used=3
#       percept={'price': 253, 'instock': 10}
# i=26 action={'buy': 0}
# i=26 used=3
#       percept={'price': 246, 'instock': 7}
# i=27 action={'buy': 5}
# i=27 used=2
#       percept={'price': 138, 'instock': 10}
# i=28 action={'buy': 15}
# i=28 used=4
#       percept={'price': 137, 'instock': 21}
# i=29 action={'buy': 15}
# i=29 used=1
#       percept={'price': 253, 'instock': 35}
# i=30 action={'buy': 0}
# i=30 used=6
#       percept={'price': 245, 'instock': 29}
# i=31 action={'buy': 0}
# i=31 used=2
#       percept={'price': 258, 'instock': 27}
# i=32 action={'buy': 0}
# i=32 used=5
#       percept={'price': 256, 'instock': 22}
# i=33 action={'buy': 0}
# i=33 used=4
#       percept={'price': 241, 'instock': 18}
# i=34 action={'buy': 0}
# i=34 used=1
#       percept={'price': 236, 'instock': 17}
# i=35 action={'buy': 0}
# i=35 used=3
#       percept={'price': 241, 'instock': 14}
# i=36 action={'buy': 0}
# i=36 used=3
#       percept={'price': 240, 'instock': 11}
# i=37 action={'buy': 0}
# i=37 used=3
#       percept={'price': 247, 'instock': 8}
# i=38 action={'buy': 5}
# i=38 used=2
#       percept={'price': 245, 'instock': 11}
# i=39 action={'buy': 0}
# i=39 used=1
#       percept={'price': 243, 'instock': 10}
# i=40 action={'buy': 0}
# i=40 used=6
#       percept={'price': 239, 'instock': 4}
# i=41 action={'buy': 5}
# i=41 used=3
#       percept={'price': 247, 'instock': 6}
# i=42 action={'buy': 5}
# i=42 used=2
#       percept={'price': 250, 'instock': 9}
# i=43 action={'buy': 5}
# i=43 used=1
#       percept={'price': 195, 'instock': 13}
# i=44 action={'buy': 0}
# i=44 used=2
#       percept={'price': 199, 'instock': 11}
# i=45 action={'buy': 0}
# i=45 used=4
#       percept={'price': 238, 'instock': 7}
# i=46 action={'buy': 5}
# i=46 used=4
#       percept={'price': 243, 'instock': 8}
# i=47 action={'buy': 5}
# i=47 used=3
#       percept={'price': 246, 'instock': 10}
# i=48 action={'buy': 0}
# i=48 used=2
#       percept={'price': 242, 'instock': 8}
# i=49 action={'buy': 5}
# i=49 used=2
#       percept={'price': 251, 'instock': 11}
# i=50 action={'buy': 0}
# i=50 used=1
#       percept={'price': 250, 'instock': 10}
# i=51 action={'buy': 0}
# i=51 used=2
#       percept={'price': 251, 'instock': 8}
# i=52 action={'buy': 5}
# i=52 used=3
#       percept={'price': 244, 'instock': 10}
# i=53 action={'buy': 0}
# i=53 used=4
#       percept={'price': 251, 'instock': 6}
# i=54 action={'buy': 5}
# i=54 used=3
#       percept={'price': 247, 'instock': 8}
# i=55 action={'buy': 5}
# i=55 used=6
#       percept={'price': 188, 'instock': 7}
# i=56 action={'buy': 5}
# i=56 used=1
#       percept={'price': 242, 'instock': 11}
# i=57 action={'buy': 0}
# i=57 used=3
#       percept={'price': 239, 'instock': 8}
# i=58 action={'buy': 5}
# i=58 used=5
#       percept={'price': 246, 'instock': 8}
# i=59 action={'buy': 5}
# i=59 used=3
#       percept={'price': 248, 'instock': 10}
# i=60 action={'buy': 0}
# i=60 used=1
#       percept={'price': 253, 'instock': 9}
# i=61 action={'buy': 5}
# i=61 used=6
#       percept={'price': 245, 'instock': 8}
# i=62 action={'buy': 5}
# i=62 used=1
#       percept={'price': 245, 'instock': 12}
# i=63 action={'buy': 0}
# i=63 used=1
#       percept={'price': 244, 'instock': 11}
# i=64 action={'buy': 0}
# i=64 used=3
#       percept={'price': 245, 'instock': 8}
# i=65 action={'buy': 5}
# i=65 used=3
#       percept={'price': 247, 'instock': 10}
# i=66 action={'buy': 0}
# i=66 used=6
#       percept={'price': 241, 'instock': 4}
# i=67 action={'buy': 5}
# i=67 used=1
#       percept={'price': 240, 'instock': 8}
# i=68 action={'buy': 5}
# i=68 used=3
#       percept={'price': 240, 'instock': 10}
# i=69 action={'buy': 0}
# i=69 used=3
#       percept={'price': 263, 'instock': 7}
# i=70 action={'buy': 5}
# i=70 used=2
#       percept={'price': 268, 'instock': 10}
# i=71 action={'buy': 0}
# i=71 used=2
#       percept={'price': 281, 'instock': 8}
# i=72 action={'buy': 5}
# i=72 used=1
#       percept={'price': 279, 'instock': 12}
# i=73 action={'buy': 0}
# i=73 used=3
#       percept={'price': 213, 'instock': 9}
# i=74 action={'buy': 5}
# i=74 used=2
#       percept={'price': 210, 'instock': 12}
# i=75 action={'buy': 0}
# i=75 used=3
#       percept={'price': 214, 'instock': 9}
# i=76 action={'buy': 5}
# i=76 used=5
#       percept={'price': 237, 'instock': 9}
# i=77 action={'buy': 5}
# i=77 used=1
#       percept={'price': 236, 'instock': 13}
# i=78 action={'buy': 0}
# i=78 used=3
#       percept={'price': 244, 'instock': 10}
# i=79 action={'buy': 0}
# i=79 used=2
#       percept={'price': 240, 'instock': 8}
# i=80 action={'buy': 5}
# i=80 used=2
#       percept={'price': 205, 'instock': 11}
# i=81 action={'buy': 0}
# i=81 used=1
#       percept={'price': 208, 'instock': 10}
# i=82 action={'buy': 0}
# i=82 used=1
#       percept={'price': 276, 'instock': 9}
# i=83 action={'buy': 5}
# i=83 used=2
#       percept={'price': 286, 'instock': 12}
# i=84 action={'buy': 0}
# i=84 used=3
#       percept={'price': 242, 'instock': 9}
# i=85 action={'buy': 5}
# i=85 used=4
#       percept={'price': 244, 'instock': 10}
# i=86 action={'buy': 0}
# i=86 used=3
#       percept={'price': 242, 'instock': 7}
# i=87 action={'buy': 5}
# i=87 used=2
#       percept={'price': 243, 'instock': 10}
# i=88 action={'buy': 0}
# i=88 used=5
#       percept={'price': 257, 'instock': 5}
# i=89 action={'buy': 5}
# i=89 used=3
#       percept={'price': 257, 'instock': 7}
# i=90 action={'buy': 5}
# i=90 used=5
#       percept={'price': 258, 'instock': 7}
# i=91 action={'buy': 5}
# i=91 used=4
#       percept={'price': 257, 'instock': 8}
# i=92 action={'buy': 5}
# i=92 used=3
#       percept={'price': 257, 'instock': 10}
# i=93 action={'buy': 0}
# i=93 used=3
#       percept={'price': 249, 'instock': 7}
# i=94 action={'buy': 5}
# i=94 used=6
#       percept={'price': 252, 'instock': 6}
# i=95 action={'buy': 5}
# i=95 used=6
#       percept={'price': 248, 'instock': 5}
# i=96 action={'buy': 5}
# i=96 used=2
#       percept={'price': 250, 'instock': 8}
# i=97 action={'buy': 5}
# i=97 used=5
#       percept={'price': 250, 'instock': 8}
# i=98 action={'buy': 5}
# i=98 used=1
#       percept={'price': 240, 'instock': 12}
# i=99 action={'buy': 0}
# i=99 used=1
#       percept={'price': 248, 'instock': 11}

# %%
sim.go(100);
print(f"agent spent ${ag.spent/100}")
pl = Plot_history(ag,env); pl.plot_env_hist(); pl.plot_agent_hist()
# Out:
# i=0 action={'buy': 0}
# i=0 used=4
#       percept={'price': 253, 'instock': 7}
# i=1 action={'buy': 5}
# i=1 used=1
#       percept={'price': 250, 'instock': 11}
# i=2 action={'buy': 0}
# i=2 used=1
#       percept={'price': 256, 'instock': 10}
# i=3 action={'buy': 0}
# i=3 used=4
#       percept={'price': 261, 'instock': 6}
# i=4 action={'buy': 5}
# i=4 used=2
#       percept={'price': 147, 'instock': 9}
# i=5 action={'buy': 15}
# i=5 used=3
#       percept={'price': 148, 'instock': 21}
# i=6 action={'buy': 15}
# i=6 used=5
#       percept={'price': 259, 'instock': 31}
# i=7 action={'buy': 0}
# i=7 used=5
#       percept={'price': 267, 'instock': 26}
# i=8 action={'buy': 0}
# i=8 used=3
#       percept={'price': 266, 'instock': 23}
# i=9 action={'buy': 0}
# i=9 used=3
#       percept={'price': 259, 'instock': 20}
# i=10 action={'buy': 0}
# i=10 used=5
#       percept={'price': 248, 'instock': 15}
# i=11 action={'buy': 0}
# i=11 used=1
#       percept={'price': 246, 'instock': 14}
# i=12 action={'buy': 0}
# i=12 used=4
#       percept={'price': 258, 'instock': 10}
# i=13 action={'buy': 0}
# i=13 used=3
#       percept={'price': 257, 'instock': 7}
# i=14 action={'buy': 5}
# i=14 used=6
#       percept={'price': 262, 'instock': 6}
# i=15 action={'buy': 5}
# i=15 used=5
#       percept={'price': 263, 'instock': 6}
# i=16 action={'buy': 5}
# i=16 used=4
#       percept={'price': 276, 'instock': 7}
# i=17 action={'buy': 5}
# i=17 used=2
#       percept={'price': 279, 'instock': 10}
# i=18 action={'buy': 0}
# i=18 used=1
#       percept={'price': 284, 'instock': 9}
# i=19 action={'buy': 5}
# i=19 used=2
#       percept={'price': 287, 'instock': 12}
# i=20 action={'buy': 0}
# i=20 used=5
#       percept={'price': 231, 'instock': 7}
# i=21 action={'buy': 5}
# i=21 used=5
#       percept={'price': 232, 'instock': 7}
# i=22 action={'buy': 5}
# i=22 used=4
#       percept={'price': 276, 'instock': 8}
# i=23 action={'buy': 5}
# i=23 used=3
#       percept={'price': 272, 'instock': 10}
# i=24 action={'buy': 0}
# i=24 used=2
#       percept={'price': 275, 'instock': 8}
# i=25 action={'buy': 5}
# i=25 used=2
#       percept={'price': 279, 'instock': 11}
# i=26 action={'buy': 0}
# i=26 used=1
#       percept={'price': 286, 'instock': 10}
# i=27 action={'buy': 0}
# i=27 used=5
#       percept={'price': 284, 'instock': 5}
# i=28 action={'buy': 5}
# i=28 used=6
#       percept={'price': 290, 'instock': 4}
# i=29 action={'buy': 5}
# i=29 used=6
#       percept={'price': 296, 'instock': 3}
# i=30 action={'buy': 5}
# i=30 used=3
#       percept={'price': 302, 'instock': 5}
# i=31 action={'buy': 5}
# i=31 used=1
#       percept={'price': 299, 'instock': 9}
# i=32 action={'buy': 5}
# i=32 used=4
#       percept={'price': 232, 'instock': 10}
# i=33 action={'buy': 0}
# i=33 used=3
#       percept={'price': 290, 'instock': 7}
# i=34 action={'buy': 5}
# i=34 used=2
#       percept={'price': 281, 'instock': 10}
# i=35 action={'buy': 0}
# i=35 used=2
#       percept={'price': 278, 'instock': 8}
# i=36 action={'buy': 5}
# i=36 used=2
#       percept={'price': 265, 'instock': 11}
# i=37 action={'buy': 0}
# i=37 used=1
#       percept={'price': 276, 'instock': 10}
# i=38 action={'buy': 0}
# i=38 used=2
#       percept={'price': 275, 'instock': 8}
# i=39 action={'buy': 5}
# i=39 used=3
#       percept={'price': 275, 'instock': 10}
# i=40 action={'buy': 0}
# i=40 used=6
#       percept={'price': 279, 'instock': 4}
# i=41 action={'buy': 5}
# i=41 used=1
#       percept={'price': 281, 'instock': 8}
# i=42 action={'buy': 5}
# i=42 used=3
#       percept={'price': 275, 'instock': 10}
# i=43 action={'buy': 0}
# i=43 used=3
#       percept={'price': 270, 'instock': 7}
# i=44 action={'buy': 5}
# i=44 used=5
#       percept={'price': 268, 'instock': 7}
# i=45 action={'buy': 5}
# i=45 used=5
#       percept={'price': 267, 'instock': 7}
# i=46 action={'buy': 5}
# i=46 used=6
#       percept={'price': 289, 'instock': 6}
# i=47 action={'buy': 5}
# i=47 used=6
#       percept={'price': 285, 'instock': 5}
# i=48 action={'buy': 5}
# i=48 used=4
#       percept={'price': 315, 'instock': 6}
# i=49 action={'buy': 5}
# i=49 used=1
#       percept={'price': 314, 'instock': 10}
# i=50 action={'buy': 0}
# i=50 used=3
#       percept={'price': 248, 'instock': 7}
# i=51 action={'buy': 5}
# i=51 used=6
#       percept={'price': 254, 'instock': 6}
# i=52 action={'buy': 5}
# i=52 used=2
#       percept={'price': 256, 'instock': 9}
# i=53 action={'buy': 5}
# i=53 used=2
#       percept={'price': 287, 'instock': 12}
# i=54 action={'buy': 0}
# i=54 used=1
#       percept={'price': 290, 'instock': 11}
# i=55 action={'buy': 0}
# i=55 used=6
#       percept={'price': 287, 'instock': 5}
# i=56 action={'buy': 5}
# i=56 used=6
#       percept={'price': 293, 'instock': 4}
# i=57 action={'buy': 5}
# i=57 used=4
#       percept={'price': 258, 'instock': 5}
# i=58 action={'buy': 5}
# i=58 used=1
#       percept={'price': 259, 'instock': 9}
# i=59 action={'buy': 5}
# i=59 used=2
#       percept={'price': 342, 'instock': 12}
# i=60 action={'buy': 0}
# i=60 used=3
#       percept={'price': 339, 'instock': 9}
# i=61 action={'buy': 5}
# i=61 used=4
#       percept={'price': 299, 'instock': 10}
# i=62 action={'buy': 0}
# i=62 used=3
#       percept={'price': 285, 'instock': 7}
# i=63 action={'buy': 5}
# i=63 used=1
#       percept={'price': 289, 'instock': 11}
# i=64 action={'buy': 0}
# i=64 used=4
#       percept={'price': 282, 'instock': 7}
# i=65 action={'buy': 5}
# i=65 used=1
#       percept={'price': 304, 'instock': 11}
# i=66 action={'buy': 0}
# i=66 used=4
#       percept={'price': 304, 'instock': 7}
# i=67 action={'buy': 5}
# i=67 used=2
#       percept={'price': 305, 'instock': 10}
# i=68 action={'buy': 0}
# i=68 used=3
#       percept={'price': 304, 'instock': 7}
# i=69 action={'buy': 5}
# i=69 used=3
#       percept={'price': 312, 'instock': 9}
# i=70 action={'buy': 5}
# i=70 used=5
#       percept={'price': 315, 'instock': 9}
# i=71 action={'buy': 5}
# i=71 used=1
#       percept={'price': 317, 'instock': 13}
# i=72 action={'buy': 0}
# i=72 used=5
#       percept={'price': 317, 'instock': 8}
# i=73 action={'buy': 5}
# i=73 used=6
#       percept={'price': 326, 'instock': 7}
# i=74 action={'buy': 5}
# i=74 used=2
#       percept={'price': 328, 'instock': 10}
# i=75 action={'buy': 0}
# i=75 used=1
#       percept={'price': 317, 'instock': 9}
# i=76 action={'buy': 5}
# i=76 used=1
#       percept={'price': 317, 'instock': 13}
# i=77 action={'buy': 0}
# i=77 used=2
#       percept={'price': 332, 'instock': 11}
# i=78 action={'buy': 0}
# i=78 used=2
#       percept={'price': 332, 'instock': 9}
# i=79 action={'buy': 5}
# i=79 used=3
#       percept={'price': 333, 'instock': 11}
# i=80 action={'buy': 0}
# i=80 used=4
#       percept={'price': 336, 'instock': 7}
# i=81 action={'buy': 5}
# i=81 used=2
#       percept={'price': 223, 'instock': 10}
# i=82 action={'buy': 0}
# i=82 used=3
#       percept={'price': 214, 'instock': 7}
# i=83 action={'buy': 5}
# i=83 used=3
#       percept={'price': 325, 'instock': 9}
# i=84 action={'buy': 5}
# i=84 used=6
#       percept={'price': 315, 'instock': 8}
# i=85 action={'buy': 5}
# i=85 used=3
#       percept={'price': 325, 'instock': 10}
# i=86 action={'buy': 0}
# i=86 used=1
#       percept={'price': 323, 'instock': 9}
# i=87 action={'buy': 5}
# i=87 used=3
#       percept={'price': 300, 'instock': 11}
# i=88 action={'buy': 0}
# i=88 used=2
#       percept={'price': 297, 'instock': 9}
# i=89 action={'buy': 5}
# i=89 used=5
#       percept={'price': 307, 'instock': 9}
# i=90 action={'buy': 5}
# i=90 used=3
#       percept={'price': 313, 'instock': 11}
# i=91 action={'buy': 0}
# i=91 used=3
#       percept={'price': 318, 'instock': 8}
# i=92 action={'buy': 5}
# i=92 used=4
#       percept={'price': 312, 'instock': 9}
# i=93 action={'buy': 5}
# i=93 used=1
#       percept={'price': 311, 'instock': 13}
# i=94 action={'buy': 0}
# i=94 used=2
#       percept={'price': 315, 'instock': 11}
# i=95 action={'buy': 0}
# i=95 used=3
#       percept={'price': 319, 'instock': 8}
# i=96 action={'buy': 5}
# i=96 used=3
#       percept={'price': 320, 'instock': 10}
# i=97 action={'buy': 0}
# i=97 used=1
#       percept={'price': 257, 'instock': 9}
# i=98 action={'buy': 5}
# i=98 used=1
#       percept={'price': 258, 'instock': 13}
# i=99 action={'buy': 0}
# i=99 used=1
#       percept={'price': 304, 'instock': 12}
# agent spent $1556.45

# %% [markdown]
# # **Task 2**
#
# # Trading Agent for Smartphone Inventory Management:
#
# **Percepts**:
#
# The agent receives two percepts:
#
# * **Price:** The current price of a specific smartphone model.
# * **Amount in Stock:** The quantity of that smartphone model available in the store.
#
# **Decision Process:**
#
# * The agent’s goal is to optimize stock levels while minimizing costs.
# * It must decide whether to order more smartphones and, if so, how many to order.
#
# **Decision Rules:**
# * If the price of the smartphone drops significantly (indicating a deal or promotion), the agent considers ordering more units.
#
# **Threshold:** Let’s say the threshold is a 20% discount from the average price.
#
# * If the amount in stock falls below a certain level (e.g., 10 units), the agent prioritizes restocking.
# * Otherwise, the agent decides not to place an order.
#
# **Actions:**
#
# * If the smartphone price is below the threshold (20% discount) and the stock level is not critically low, the agent orders a specific quantity (let’s call it tobuy).
#
#
# > **Example:** If the smartphone price drops to 500 BDT (from an average of 600 BDT) and there are 20 units in stock, the agent might decide to order 15 more units.
#
#
# * If the stock level is critically low (e.g., less than 10), the agent orders a minimum quantity (e.g., 10 units).
# * Otherwise, if neither condition is met, the agent does not place an order (i.e., tobuy = 0).

# %%
class SmartphoneAgent:
    def __init__(self, threshold_discount=0.2, critical_stock_level=10):
        self.threshold_discount = threshold_discount
        self.critical_stock_level = critical_stock_level
        self.average_price = None
        self.stock_level = None

    def UpdatePercepts(self, price,stock_amount):
        self.average_price = price
        self.stock_level = stock_amount

    def MakeDecision(self):
        if self.average_price is None or self.stock_level is None:
            return 0

        tobuy = 0

        if self.average_price * (1 - self.threshold_discount) > price:
            if self.stock_level < self.critical_stock_level:
                tobuy = max(10, self.critical_stock_level - self.stock_level)
            else:
                tobuy = min(15, 50 - self.stock_level)

        return tobuy

# %%
agent = SmartphoneAgent(threshold_discount=0.2, critical_stock_level=10)
agent.UpdatePercepts(600, 20)
price = 500
tobuy = agent.MakeDecision()
if tobuy > 0:
        print(f"Agent decided to order {tobuy} units.")
else:
        print("Agent decided not to place an order.")
# Out:
# Agent decided not to place an order.
